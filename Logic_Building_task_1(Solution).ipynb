# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshatMishra29/Innomatics_Internship_Assignments/blob/main/Logic_Building_task_1(Solution).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data-Science Intersnship - Februrary 2026**
#
#
# ##**Logic building Task-1**
#
#
# ---
#
#
# ##1. **User Login Check**
# **Problem Statement:**
#
# Given a username and password, check whether login is successful.
# username = "admin"
# password = "1234"
#
# ###**Requirements:**
# ● Print "Login Successful" if both username and password match
#
# ● Otherwise print "Invalid Credentials"
# Real-World Application: Authentication systems

# %%
# creating a function for checking username and password\

def user_login_check(username,password):

  if username == "admin" and password == "1234":
    print("Login Successful")

  else:

    print("Invlaid Credentials")



if __name__ == "__main__":

  username = input("Enter the username:")
  password = input("Enter the password:")

  user_login_check(username,password)

#
# Out:
# Enter the username:admin
# Enter the password:1234
# Login Successful

# %% [markdown]
# ##2. **Pass / Fail Analyzer**
#
# **Problem Statement:**
# Analyze student results.
# marks = [45, 78, 90, 33, 60]
#
# **Requirements:**
#
# ● A student passes if marks ≥ 50
#
# ● Count the total number of pass students
#
# ● Count the total number of fail students
#
# ● Print the final result clearly
# Real-World Application: Academic evaluation systems

# %%
def Pass_Fail_Analyzer(marks):
  pass_count = 0
  fail_count = 0

  for mark in marks:
    if mark>=50:
      pass_count += 1
    else:
      fail_count +=1

  print(f"Total Number of student passed in the test: {pass_count}")
  print(f"Total Number of student failed in the test: {fail_count}")


if __name__ == "__main__" :

   marks = [45,78,90,33,60]
   print("Analyzing student result:")
   Pass_Fail_Analyzer(marks)
# Out:
# Analyzing student result:
# Total Number of student passed in the test: 3
# Total Number of student failed in the test: 2

# %% [markdown]
# ## 3. **Simple Data Cleaner**
#
# **Problem Statement:**
#
# Clean and standardize user names.
# names = [" Alice ", "bob", " CHARLIE "]
#
# **Requirements:**
#
# ● Remove extra spaces
#
# ● Convert all names to lowercase
#
# ● Print the cleaned list
#
# Real-World Application: Data preprocessing before analysis

# %%
def message_length_analyzer(messages):
  for message in messages:
    length = len(message)
    print(f"Message: '{message}', Length: {length}")
    if length > 10:
      print("  (This message is longer than 10 characters)")

if __name__ == "__main__":
  messages = ["Hi", "Welcome to the platform", "OK"]
  print("Analyzing message lengths:")
  message_length_analyzer(messages)
# Out:
# Analyzing message lengths:
# Message: 'Hi', Length: 2
# Message: 'Welcome to the platform', Length: 23
#   (This message is longer than 10 characters)
# Message: 'OK', Length: 2

# %% [markdown]
# ##4. **Message Length Analyzer**
#
# **Problem Statement:**
#
# Analyze message sizes.
#
# messages = ["Hi", "Welcome to the platform", "OK"]
#
# **Requirements:**
#
# ● Print the length of each message
#
# ● Flag messages longer than 10 characters
#
# Real-World Application: Text filtering and validation systems

# %%
class Solution:
    def messageLengthAnalyzer(self, messages):
        for msg in messages:
            length = len(msg)  # Calculate once (optimized)
            print(f"Message: '{msg}' | Length: {length}")

            if length > 10:
                print("⚠️ Flag: Message longer than 10 characters")

# %%
def MsgAnalyzer(message):


  for msg in messages:
    length = len(msg)
    print(f"Message:'{msg} and length:{length}")


    if length>10:
      print("Mssg not logner than 10 characters")


if __name__ == "__main__":

  messages = ["Hi", "Welcome to the platform", "OK"]

  print("Analyzing message lengths:")
  MsgAnalyzer(messages)
# Out:
# Analyzing message lengths:
# Message:'Hi and length:2
# Message:'Welcome to the platform and length:23
# Mssg not logner than 10 characters
# Message:'OK and length:2

# %% [markdown]
# ##5. **Error Message Detector**
#
# **Problem Statement:**
#
# Detect error messages from system logs.
#
# logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# **Requirements:**
#
# - Count the number of "ERROR" entries
#
# - Print the total error count

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

count = 0

for log in logs:
    if log == "ERROR":
        count = count + 1

print("Total Error Count:", count)

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

count = 0

for log in logs:
    if log == "ERROR":
        count = count + 1

print(f"The number of ERROR in the list is {count}")
# Out:
# The number of ERROR in the list is 2
